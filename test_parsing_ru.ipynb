# %%
import parsing_model_ru

# %%
# Проверка
dataset = "В японском языке звук [t] в начальной позиции первого слога ассоциируется обычно с чем-то легким, маленьким и приятным, а в начальной позиции второго слога – означает «полную гармонию»."
parsing_model_ru.Syntax_model_processing_text(dataset)
# Out:
# Вывод разультата обработки текста моделью:
#
# В ADP case языке
# японском ADJ amod языке
# языке NOUN obl ассоциируется
# звук NOUN nsubj ассоциируется
# [ PUNCT punct t
# t PROPN appos звук
# ] PUNCT punct t
# в ADP case позиции
# начальной ADJ amod позиции
# позиции NOUN obl ассоциируется
# первого ADJ amod слога
# слога NOUN nmod позиции
# ассоциируется VERB ROOT ассоциируется
# обычно ADV advmod ассоциируется
# с ADP case чем
# чем PRON obl ассоциируется
# - PRON obl ассоциируется
# то PRON obl ассоциируется
# легким NOUN obl ассоциируется
# , PUNCT punct маленьким
# маленьким ADJ conj легким
# и CCONJ cc приятным
# приятным ADJ conj легким
# , PUNCT punct означает
# а CCONJ cc означает
# в ADP case позиции
# начальной ADJ amod позиции
# позиции NOUN obl означает
# второго ADJ amod слога
# слога NOUN nmod позиции
# – PUNCT punct позиции
# означает VERB conj ассоциируется
# « PUNCT punct гармонию
# полную ADJ amod гармонию
# гармонию NOUN obj означает
# » PUNCT punct гармонию
# ...
